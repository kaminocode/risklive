# %%
import pandas as pd
from datetime import datetime
from risklive.config import SAVE_DIR
from risklive.data_extraction import aggregate_news_data

# %%
df = aggregate_trending_news(save_folder=SAVE_DIR["CSV_DATA_DIR"])
display(df)
# Out:
# Invalid country_code. Must be one of: ALL, AR, AT, AU, BE, BR, CA, CH, CL, CN, DE, DK, ES, FI, FR, GB, HK, ID, IN, IT, JP, KR, MX, MY, NL, NO, NZ, PH, PL, PT, RU, SA, SE, TR, TW, US, ZA
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = aggregate_trending_news(save_folder=SAVE_DIR["CSV_DATA_DIR"])
#       2 display(df)
#
# File ~/PycharmProjects/risklive/risklive/data_extraction/bing_api.py:193, in aggregate_trending_news(days, save_folder)
#     190     full_news_df = pd.DataFrame()
#     192 since_date = int((datetime.now() - pd.DateOffset(days=days)).timestamp())
# --> 193 trending_topics_df = search_news_for_trending_topics(since_date)
#     195 full_news_df = pd.concat(
#     196     [full_news_df, trending_topics_df],
#     197     ignore_index=True,
#     198 ).drop_duplicates(subset=["URL"], keep="first")
# ...

# %%
df = aggregate_trending_news(save_folder=SAVE_DIR["CSV_DATA_DIR"])
display(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = aggregate_trending_news(save_folder=SAVE_DIR["CSV_DATA_DIR"])
#       2 display(df)
#
# NameError: name 'aggregate_trending_news' is not defined

# %%
df = aggregate_news_data(save_folder=SAVE_DIR["CSV_DATA_DIR"])
display(df)
# Out:
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 0 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 5 results.
# Retrieved 0 results.
# Retrieved 0 results.
# Retrieved 0 results.
# Retrieved 0 results.
# Retrieved 5 results.
# Retrieved 0 results.
# Retrieved 0 results.
# Retrieved 0 results.
#                                                 Title  \
# 0   Latest Business News | Financial News | Stock ...
# 1   Spaceship Levels Up Business Email Communicati...
# 2   Understanding Business Statistics: A Comprehen...
# 3   Business Cycle Mutual Funds: What Are These, W...
# 4   12 Entrepreneurs Redefining India’s Business L...
# ..                                                ...
# ...

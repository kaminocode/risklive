# %%
import pandas as pd
from datetime import datetime
from config import SAVE_DIR
from data_extraction import search_news_for_trending_topics, extract_news_by_category, search_news, aggregate_news_data, aggregate_regular_news, aggregate_trending_news

# %%
df = aggregate_trending_news(save_folder=SAVE_DIR["CSV_DATA_DIR"])
display(df)
# Out:
#                                                 Title  \
# 0   ‘Astonishing’ surge in pensioners paying top t...
# 1   Apollo swoops for parcel delivery giant Evri i...
# 2   Revolut's new banking licence is fantastic new...
# 3   Biggest US tech sell-off for over a decade ref...
# 4   50 of the best funds and investment trusts: Ou...
# ..                                                ...
# 17  Rayner’s pay reforms doomed to fail without bu...
# 18  Fallout: London is finally out today and can b...
# 19  Martin Lewis explains how millions of pensione...
# 20  The reason your garden is full of slugs, snail...
# 21  FBI director casts doubts on Trump being struc...
#
#                                                   URL  \
# 0   https://www.msn.com/en-gb/money/other/astonish...
# 1   https://www.msn.com/en-gb/money/news/apollo-sw...
# 2   https://www.msn.com/en-gb/money/other/revoluts...
# 3   https://www.msn.com/en-gb/money/other/biggest-...
# ...

# %%
df = aggregate_trending_news(save_folder=SAVE_DIR["CSV_DATA_DIR"])
display(df)
# Out:
#                                                  Title  \
# 0    Lloyds earnings dip as boost from borrowing co...
# 1    More details on Great British Energy plan - as...
# 2    50 of the best funds and investment trusts: Ou...
# 3    British Gas owner sees profits slump as energy...
# 4    This is the moment to champion cash and ensure...
# ..                                                 ...
# 196  Bin strikes: Councils ask Scottish Government ...
# 197  Russian and Chinese military aircraft intercep...
# 0    Ukraine-Russia latest: Putin pulls last Russia...
# 4    Russia scrambles fighter jets to escort RAF Ty...
# 14   Northern Lights to stretch to UK and US tonigh...
#
#                                                    URL  \
# 0    https://www.msn.com/en-gb/money/other/lloyds-e...
# 1    https://www.msn.com/en-gb/news/uknews/more-det...
# 2    https://www.msn.com/en-gb/money/other/50-of-th...
# 3    https://www.msn.com/en-gb/money/other/british-...
# ...

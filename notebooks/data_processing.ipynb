# %%
import os
import pandas as pd
from datetime import datetime
from config import SAVE_DIR
from data_processing import extract_information, process_df
from data_extraction import aggregate_news_data

# %%
df = pd.read_csv(os.path.join(SAVE_DIR['CSV_DATA_DIR'], 'news_data.csv'))

# %%
extracted_df = process_df(df, save_folder = SAVE_DIR['CSV_DATA_DIR'])

# %%
extracted_df.keys()
# Out:
# Index(['Title', 'URL', 'Description', 'Timestamp', 'IsTrending',
#        'LLM_Response', 'LLM_Price', 'LLM_Token_Usage', 'PromptTokens',
#        'CompletionTokens', 'TotalTokens', 'RelevantKeywords', 'ShortSummary',
#        'Relevance', 'RelevanceReason', 'AlertFlag', 'AlertReason',
#        'NewsCategory', 'API_Timestamp'],
#       dtype='object')

# %%
extracted_df.head()
# Out:
#                                                Title  \
# 0  Lloyds earnings dip as boost from borrowing co...
# 1  More details on Great British Energy plan - as...
# 2  50 of the best funds and investment trusts: Ou...
# 3  British Gas owner sees profits slump as energy...
# 4  This is the moment to champion cash and ensure...
#
#                                                  URL  \
# 0  https://www.msn.com/en-gb/money/other/lloyds-e...
# 1  https://www.msn.com/en-gb/news/uknews/more-det...
# 2  https://www.msn.com/en-gb/money/other/50-of-th...
# 3  https://www.msn.com/en-gb/money/other/british-...
# 4  https://www.msn.com/en-gb/money/other/this-is-...
#
#                                          Description  \
# 0  Lloyds earnings dip as boost from borrowing co...
# 1  The government is teaming up with the Crown Es...
# 2  We asked trusted experts to recommend the best...
# 3  British Gas owner sees profits slump as energy...
# 4  After years of being mollycoddled into paying ...
#
#                       Timestamp IsTrending  \
# 0  2024-07-25T06:54:00.0000000Z         no
# 1  2024-07-25T03:43:00.0000000Z         no
# 2  2024-07-25T05:19:00.0000000Z         no
# 3  2024-07-25T07:09:00.0000000Z         no
# 4  2024-07-25T05:20:00.0000000Z         no
#
#                                         LLM_Response  LLM_Price  \
# 0  {'RelevantKeywords': ['Lloyds', 'earnings', 'b...   0.006534
# 1  {'RelevantKeywords': ['Great British Energy', ...   0.006352
# 2  {'RelevantKeywords': ['funds', 'investment tru...   0.006344
# 3  {'RelevantKeywords': ['British Gas', 'Centrica...   0.006800
# 4  {'RelevantKeywords': ['cash', 'payment choice'...   0.006360
#
#                                      LLM_Token_Usage  PromptTokens  \
# 0  CompletionUsage(completion_tokens=136, prompt_...          1229
# 1  CompletionUsage(completion_tokens=122, prompt_...          1225
# 2  CompletionUsage(completion_tokens=121, prompt_...          1226
# 3  CompletionUsage(completion_tokens=156, prompt_...          1236
# 4  CompletionUsage(completion_tokens=118, prompt_...          1239
#
#    CompletionTokens  TotalTokens  \
# 0               136         1365
# 1               122         1347
# 2               121         1347
# 3               156         1392
# 4               118         1357
#
#                                     RelevantKeywords  \
# 0  Lloyds, earnings, borrowing costs, pre-tax profit
# 1  Great British Energy, Crown Estate, offshore w...
# 2  funds, investment trusts, experts, investment ...
# 3  British Gas, Centrica, profits slump, energy m...
# 4            cash, payment choice, card transactions
#
#                                         ShortSummary Relevance  \
# 0  Lloyds reported a dip in earnings with a pre-t...        No
# 1  The government is collaborating with the Crown...        No
# 2  Experts recommend the best funds and investmen...        No
# 3  Centrica, the owner of British Gas, reported a...        No
# 4  Lee Boyce advocates for the preservation of ca...        No
#
#   RelevanceReason AlertFlag  \
# 0              NA     Green
# 1              NA     Green
# 2              NA     Green
# 3              NA     Green
# 4              NA     Green
#
#                                          AlertReason   NewsCategory  \
# 0  The article discusses financial performance of...  miscellaneous
# 1  The article discusses the development of offsh...  miscellaneous
# 2  The article is about investment funds and trus...  miscellaneous
# 3  The article discusses the financial performanc...  miscellaneous
# 4  The article discusses the importance of cash a...  miscellaneous
#
#          API_Timestamp
# 0  2024-07-25 09:05:30
# 1  2024-07-25 09:05:34
# 2  2024-07-25 09:05:37
# 3  2024-07-25 09:05:39
# 4  2024-07-25 09:05:45

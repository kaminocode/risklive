# %%
import pandas as pd

# %%
data_path = "../results/data/news_data_with_llm_info.csv"
df = pd.read_csv(data_path)

# %%
df_relevant = df[df["Relevance"] == "Yes"]

# %%
df_relevant.NewsCategory.unique()
# Out:
# array([], dtype=float64)

# %%
df_relevant
# Out:
# Empty DataFrame
# Columns: [Title, URL, Description, Timestamp, Query, LLM_Response, LLM_Price, LLM_Token_Usage, PromptTokens, CompletionTokens, TotalTokens, RelevantKeywords, ShortSummary, Relevance, RelevanceReason, AlertFlag, AlertReason, NewsCategory, API_Timestamp]
# Index: []
